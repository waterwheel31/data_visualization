# %% [markdown]
# # Racial Group Distribution in the US

# %% [markdown]
# This is a practice to visualize where each racial group of the US is distributed

# %% [markdown]
# ### Asian people
#
# Proportion of Asian people's population is high in Calfornia and Hawaii

# %%
from IPython.display import Image
Image("./images/map1.png")

# %% [markdown]
# Especially in Hawaii, Asian people are the largest racial group

# %%
Image("./images/chart6.png")

# %% [markdown]
# When breaking into country, those people are mostly living in Honolulu County

# %%
Image("./images/chart7.png")

# %% [markdown]
# ### Hispanic people
#
# Proportion of Hispanic people's population is high in South Western states in general

# %%
Image("./images/map2.png")

# %% [markdown]
# ### Black people
#
# Proportion of Black people's population is high in South Eastern states in general

# %%
Image("./images/map3.png")

# %% [markdown]
# ### White people
#
# Proportion of White people's population is high in all states

# %%
Image("./images/map4.png")

# %% [markdown]
# ## Link to Tableau Public
#
# link to the Tableu Public page: https://public.tableau.com/profile/dslearner#!/vizhome/RacialgroupdistributionintheUS/Story1?publish=yes

# %%
# %%HTML
#
# <div class='tableauPlaceholder' id='viz1581527336888' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;2N&#47;2N35W8XG4&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;2N35W8XG4' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;2N&#47;2N35W8XG4&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1581527336888');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='1016px';vizElement.style.height='991px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1581527336888' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;2N&#47;2N35W8XG4&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;2N35W8XG4' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;2N&#47;2N35W8XG4&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement =
# ...

# %% [markdown]
# ## Design Consideration
#
# - Used map to show geographical distribution clear and meaningful
# - Separate the coloring into 3 categories with the same threshold to make it simple and compatible among four maps.

# %% [markdown]
# ## Resources
#
# - Kaggle https://www.kaggle.com/muonneutrino/us-census-demographic-data/data
